# %%
import pandas as pd
from pyomo.opt import SolverFactory, TerminationCondition
from sudoku_solver import sudoku_model, add_integer_cut, print_solution

# %%
# define the board

board = pd.read_excel('./sudoku_input.xlsx', header=None)

# %%
model = sudoku_model(board)
# Out:
#      1    2    3    4    5    6    7    8    9
# 1  5.0  3.0  NaN  NaN  7.0  NaN  NaN  NaN  NaN
# 2  6.0  NaN  NaN  1.0  9.0  5.0  NaN  NaN  NaN
# 3  NaN  9.0  8.0  NaN  NaN  NaN  NaN  6.0  NaN
# 4  8.0  NaN  NaN  NaN  6.0  NaN  NaN  NaN  3.0
# 5  4.0  NaN  NaN  8.0  NaN  3.0  NaN  NaN  1.0
# 6  7.0  NaN  NaN  NaN  2.0  NaN  NaN  NaN  6.0
# 7  NaN  6.0  NaN  NaN  NaN  NaN  2.0  8.0  NaN
# 8  NaN  NaN  NaN  4.0  1.0  9.0  NaN  NaN  5.0
# 9  NaN  NaN  NaN  NaN  8.0  NaN  NaN  7.0  9.0

# %%
solution_count = 0
while 1:
    with SolverFactory("glpk") as opt:
        results = opt.solve(model)
        if results.solver.termination_condition != TerminationCondition.optimal:
            print("All board solutions have been found")
            break

    solution_count += 1

    add_integer_cut(model)

    print("Solution #%d" % (solution_count))
    print_solution(model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 4
#       2 while 1:
#       3     with SolverFactory("glpk") as opt:
# ----> 4         results = opt.solve(model)
#       5         if results.solver.termination_condition != TerminationCondition.optimal:
#       6             print("All board solutions have been found")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pyomo\opt\base\solvers.py:570, in OptSolver.solve(self, *args, **kwds)
#     565 try:
#     566
#     567     # we're good to go.
#     568     initial_time = time.time()
# --> 570     self._presolve(*args, **kwds)
#     572     presolve_completion_time = time.time()
#     573     if self._report_timing:
#
# ...
